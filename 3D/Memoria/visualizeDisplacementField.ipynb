# %%
import numpy as np
import pandas as pd
import datetime
from pathlib import Path

import os
import pickle


import sys
import scipy.io
import matplotlib.pyplot as plt

# %%
def get_variable_name(variable, namespace):
    return [name for name in namespace if namespace[name] is variable]

# %%
path_actual = os.getcwd()
path_nirep = path_actual + "\\Memoria\\NIREP\\Campos\\"
path_oasis = path_actual + "\\Memoria\\OASIS\\Campos\\"


# NIREP
odesolver_nirep = scipy.io.loadmat(path_nirep + "V_NIREPZhangMCC_odesolver_14.mat")
fno3d_nirep = scipy.io.loadmat(path_nirep + "V_NIREPZhangMCC_fno3d_14.mat")
fno3d_0_1_nirep = scipy.io.loadmat(path_nirep + "V_NIREPZhangMCC_fno3d_0_1_14.mat")
fno3d_1_1_nirep = scipy.io.loadmat(path_nirep + "V_NIREPZhangMCC_fno3d_1_1_14.mat")

# OASIS
odesolver_oasis = scipy.io.loadmat(path_oasis + "V_OASISZhangMCC_odesolver_402.mat")
fno3d_oasis = scipy.io.loadmat(path_oasis + "V_OASISZhangMCC_fno3d_402.mat")
fno3d_0_1_oasis = scipy.io.loadmat(path_oasis + "V_OASISZhangMCC_fno3d_0_1_402.mat")
fno3d_1_1_oasis = scipy.io.loadmat(path_oasis + "V_OASISZhangMCC_fno3d_1_1_402.mat")

# %%
v0 = odesolver_nirep['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)     
v0_odesolver_nirep = v0

v0 = fno3d_nirep['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_fno3d_nirep = v0

v0 = fno3d_0_1_nirep['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_fno3d_0_1_nirep = v0

v0 = fno3d_1_1_nirep['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_fno3d_1_1_nirep = v0

v0 = odesolver_oasis['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_odesolver_oasis = v0

v0 = fno3d_oasis['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_fno3d_oasis = v0

v0 = fno3d_0_1_oasis['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_fno3d_0_1_oasis = v0

v0 = fno3d_1_1_oasis['v0']
v0 = np.squeeze(v0)
x = v0.shape[0] // 2
M = np.max(v0)
m = np.min(v0)
v0 = (v0 - m) / (M - m)
v0 = v0[x,:,:,:]
v0 = v0.transpose(1,0,2)
v0 = np.flip(v0, axis=0)
v0 = np.flip(v0, axis=1)
v0_fno3d_1_1_oasis = v0

# %%
v0_odesolver_nirep = np.asarray(v0_odesolver_nirep, dtype=np.float32)
v0_fno3d_nirep = np.asarray(v0_fno3d_nirep, dtype=np.float32)
v0_fno3d_0_1_nirep = np.asarray(v0_fno3d_0_1_nirep, dtype=np.float32)
v0_fno3d_1_1_nirep = np.asarray(v0_fno3d_1_1_nirep, dtype=np.float32)

v0_odesolver_oasis = np.asarray(v0_odesolver_oasis, dtype=np.float32)
v0_fno3d_oasis = np.asarray(v0_fno3d_oasis, dtype=np.float32)
v0_fno3d_0_1_oasis = np.asarray(v0_fno3d_0_1_oasis, dtype=np.float32)
v0_fno3d_1_1_oasis = np.asarray(v0_fno3d_1_1_oasis, dtype=np.float32)

# %%
size = 20
dpi = 200  # Aumentar DPI para mayor calidad

plt.figure(dpi=dpi)
plt.imshow(v0_odesolver_nirep)
plt.axis('off')
name = get_variable_name(v0_odesolver_nirep, globals())[0]
plt.savefig(path_nirep + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()  

plt.figure(dpi=dpi)
plt.imshow(v0_fno3d_nirep)
plt.axis('off')
name = get_variable_name(v0_fno3d_nirep, globals())[0]
plt.savefig(path_nirep + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()

plt.figure(dpi=dpi)
plt.imshow(v0_fno3d_0_1_nirep)
plt.axis('off')
name = get_variable_name(v0_fno3d_0_1_nirep, globals())[0]
plt.savefig(path_nirep + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()

plt.figure(dpi=dpi)
plt.imshow(v0_fno3d_1_1_nirep)
plt.axis('off')
name = get_variable_name(v0_fno3d_1_1_nirep, globals())[0]
plt.savefig(path_nirep + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()

plt.figure(dpi=dpi)
plt.imshow(v0_odesolver_oasis)
plt.axis('off')
name = get_variable_name(v0_odesolver_oasis, globals())[0]
plt.savefig(path_oasis + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()

plt.figure(dpi=dpi)
plt.imshow(v0_fno3d_oasis)
plt.axis('off')
name = get_variable_name(v0_fno3d_oasis, globals())[0]
plt.savefig(path_oasis + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()

plt.figure(dpi=dpi)
plt.imshow(v0_fno3d_0_1_oasis)
plt.axis('off')
name = get_variable_name(v0_fno3d_0_1_oasis, globals())[0]
plt.savefig(path_oasis + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()

plt.figure(dpi=dpi)
plt.imshow(v0_fno3d_1_1_oasis)
plt.axis('off')
name = get_variable_name(v0_fno3d_1_1_oasis, globals())[0]
plt.savefig(path_oasis + name + '.jpg', dpi=dpi, bbox_inches='tight')
plt.show()
